# %%
import seaborn as sns
df=sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df.shape
# Out:
# (244, 7)

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
correlation=df.corr(numeric_only=True)
correlation
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(correlation)
# Out:
# <Axes: >

# %%
sns.jointplot(x="total_bill",y="tip",data=df,kind="reg")

# %%
sns.jointplot(x="size",y="tip",data=df,kind="reg")

# %%
sns.pairplot(df,hue="sex")

# %%
sns.countplot(x="day",data=df)
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(x="sex",data=df,color="r")
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x="smoker",data=df,color="k")
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.countplot(x="day",data=df,hue="sex")
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(x="smoker",data=df,hue="sex")
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.countplot(x="day",data=df,hue="sex")
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.barplot(x="sex",y="total_bill",data=df,ci=None)
# Out:
# C:\Users\SHYAMA S\AppData\Local\Temp\ipykernel_18236\2437290128.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="sex",y="total_bill",data=df,ci=None)
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x="day",y="total_bill",data=df,color="k")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x="smoker",y='tip',data=df,color="m")
# Out:
# <Axes: xlabel='smoker', ylabel='tip'>

# %%
sns.boxplot(y="tip",data=df)
# Out:
# <Axes: ylabel='tip'>

# %%
sns.boxplot(x="day",y="total_bill",data=df,hue="sex")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>
