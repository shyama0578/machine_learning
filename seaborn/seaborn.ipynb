# %%
import seaborn as sns
df=sns.load_dataset('tips') #tip,titanic,iris,diamonds,penguins
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df.shape
# Out:
# (244, 7)

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
#feature selection:select necessery col
correlation=df.corr(numeric_only=True)
correlation #diagonal elemnts are one
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
#correlation matrix graphical resentation ==>heatmap
sns.heatmap(correlation)#cmap="coolwarm"
#light color=>strong correlation
#dark color=weak correlatiom
# Out:
# <Axes: >

# %%
#joinplot==>numerical value
sns.jointplot(x="total_bill",y="tip",data=df,kind="reg")#hex
#combination of hist and scatterplot
#right side tip hist
#top histogram of total_bill
#kind="reg"==>regression plot and distribution pattern
#kind="hex"==>hexagon

# %%
sns.jointplot(x="size",y="tip",data=df,kind="hex")

# %%
#pairplot(numerical variable relation multiple)
sns.pairplot(df,hue="sex")#hue ==>specific l data

# %%
#countplot ==>count of catogorical colm (instead of value count )
sns.countplot(x='sex',data=df,color="k")#only for catogorical data
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='smoker',data=df,color="k")
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.countplot(x='day',data=df,hue="sex")#hue subcondition
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(x='day',data=df,hue="smoker")
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
#barplot==>comparison btwen numerical catog
sns.barplot(x="day",y="total_bill",data=df,ci=None) #confidence interval--ci
#line==>errorbar(if variation increases error bar increases)
# Out:
# C:\Users\SHYAMA S\AppData\Local\Temp\ipykernel_17352\2237731128.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="day",y="total_bill",data=df,ci=None) #confidence interval--ci
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x="tip",y="day",data=df)
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %%
#to check outliers present in the graph we use boxplot

sns.boxplot(x="smoker",y="total_bill",data=df,color="m")
#box==>inter quartile range
#viskers==>line extend from iqr,
#upper viskers(maximum value) and lower viskers(minimum value)
#outliers==>wrondata
#q1=25th percentile
#q2 is medium
#Q3==>75 th percentile
# Out:
# <Axes: xlabel='smoker', ylabel='total_bill'>

# %%
df["total_bill"].unique()
# Out:
# array([16.99, 10.34, 21.01, 23.68, 24.59, 25.29,  8.77, 26.88, 15.04,
#        14.78, 10.27, 35.26, 15.42, 18.43, 14.83, 21.58, 10.33, 16.29,
#        16.97, 20.65, 17.92, 20.29, 15.77, 39.42, 19.82, 17.81, 13.37,
#        12.69, 21.7 , 19.65,  9.55, 18.35, 15.06, 20.69, 17.78, 24.06,
#        16.31, 16.93, 18.69, 31.27, 16.04, 17.46, 13.94,  9.68, 30.4 ,
#        18.29, 22.23, 32.4 , 28.55, 18.04, 12.54, 10.29, 34.81,  9.94,
#        25.56, 19.49, 38.01, 26.41, 11.24, 48.27, 13.81, 11.02, 17.59,
#        20.08, 16.45,  3.07, 20.23, 15.01, 12.02, 17.07, 26.86, 25.28,
#        14.73, 10.51, 27.2 , 22.76, 17.29, 19.44, 16.66, 10.07, 32.68,
#        15.98, 34.83, 13.03, 18.28, 24.71, 21.16, 28.97, 22.49,  5.75,
#        16.32, 22.75, 40.17, 27.28, 12.03, 12.46, 11.35, 15.38, 44.3 ,
#        22.42, 20.92, 15.36, 20.49, 25.21, 18.24, 14.31, 14.  ,  7.25,
#        38.07, 23.95, 25.71, 17.31, 29.93, 10.65, 12.43, 24.08, 11.69,
# ...

# %%
sns.boxplot(y="total_bill",data=df)
#outliers--above maximum range
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.boxplot(y="tip",data=df)
# Out:
# <Axes: ylabel='tip'>

# %%
sns.boxplot(y="size",data=df)
# Out:
# <Axes: ylabel='size'>

# %%
#boxplot multiple representation
sns.boxplot(x="day",y="total_bill",data=df,hue="sex")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x="smoker",y="tip",data=df,hue="sex")#x,hue=>catogorical,y=>numerical
# Out:
# <Axes: xlabel='smoker', ylabel='tip'>

# %%
# import matplotlib.pyplot as plt
# def removal_box_plot(df,column,threshold):
#     sns.boxplot(df[column])
#     plt.title(f"orginal box plot of {column}")
#     plt.show()

#     removed_outliers=df[df[column]]>=threshold

#     sns.regplot(removed_outliers[column])
#     plt.title(f'box plot withou outliers of {column}')
#     plt.show()
#     return removed_outliers

# threshold_value=40
# no_outliers=removal_box_plot(df,"total_bill",threshold_value)

# %%
import matplotlib.pyplot as plt
def removal_box_plot(df,column,threshold):
    sns.boxplot(df[column])
    plt.title(f"Original box plot of {column}")
    plt.show()

    removed_outliers=df[df[column]>=threshold]

    sns.boxplot(removed_outliers[column])
    plt.title(f'Box Plot without Outliers of {column}')
    plt.show()
    return removed_outliers

threshold_value=40
no_outliers=removal_box_plot(df,'total_bill',threshold_value)

# %%
df.shape
# Out:
# (244, 7)
