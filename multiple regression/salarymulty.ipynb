# %%
import numpy as np
import pandas as pd
df=pd.read_csv("SalaryMulti.csv")
df
# Out:
#      Total Experience  Team Lead Experience  Project Manager Experience  \
# 0                   7                     2                           4
# 1                   4                     0                           2
# 2                  13                     4                           8
# 3                  11                     3                           2
# 4                   8                     1                           6
# ..                ...                   ...                         ...
# 995                 8                     1                           6
# 996                12                     3                           1
# 997                14                    10                           1
# 998                 7                     5                           0
# 999                10                     6                           2
#
#      Certifications         Salary
# 0                 1   77318.070547
# ...

# %%
df.head()
# Out:
#    Total Experience  Team Lead Experience  Project Manager Experience  \
# 0                 7                     2                           4
# 1                 4                     0                           2
# 2                13                     4                           8
# 3                11                     3                           2
# 4                 8                     1                           6
#
#    Certifications         Salary
# 0               1   77318.070547
# 1               3   64951.950980
# 2               3  106058.185204
# 3               1   89649.944851
# 4               3   82206.019687

# %%
df.tail()
# Out:
#      Total Experience  Team Lead Experience  Project Manager Experience  \
# 995                 8                     1                           6
# 996                12                     3                           1
# 997                14                    10                           1
# 998                 7                     5                           0
# 999                10                     6                           2
#
#      Certifications         Salary
# 995               4   90941.688891
# 996               2   92074.890941
# 997               2  115914.944924
# 998               2   82706.285700
# 999               4   85347.167601

# %%
df.shape
# Out:
# (1000, 5)

# %%
df.dtypes
# Out:
# Total Experience                int64
# Team Lead Experience            int64
# Project Manager Experience      int64
# Certifications                  int64
# Salary                        float64
# dtype: object

# %%
df.isna().sum()
# Out:
# Total Experience              0
# Team Lead Experience          0
# Project Manager Experience    0
# Certifications                0
# Salary                        0
# dtype: int64

# %%
x=df.iloc[:,:-1]
x
# Out:
#      Total Experience  Team Lead Experience  Project Manager Experience  \
# 0                   7                     2                           4
# 1                   4                     0                           2
# 2                  13                     4                           8
# 3                  11                     3                           2
# 4                   8                     1                           6
# ..                ...                   ...                         ...
# 995                 8                     1                           6
# 996                12                     3                           1
# 997                14                    10                           1
# 998                 7                     5                           0
# 999                10                     6                           2
#
#      Certifications
# 0                 1
# 1                 3
# 2                 3
# ...

# %%
y=df.iloc[:,-1]
y
# Out:
# 0       77318.070547
# 1       64951.950980
# 2      106058.185204
# 3       89649.944851
# 4       82206.019687
#            ...
# 995     90941.688891
# 996     92074.890941
# 997    115914.944924
# 998     82706.285700
# 999     85347.167601
# Name: Salary, Length: 1000, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.scatter(df["Total Experience"],y)
plt.xlabel("total exp")
plt.ylabel("salary")
plt.title("exp-sal")
# Out:
# Text(0.5, 1.0, 'exp-sal')

# %%
plt.scatter(df["Team Lead Experience"],y,color="r")
plt.xlabel("lead-experiencce")
plt.ylabel("salary")
plt.title("lead exp- sal")
# Out:
# Text(0.5, 1.0, 'lead exp- sal')

# %%
plt.scatter(df["Certifications"],y,color="m")
plt.xlabel("cetification")
plt.ylabel("salary")
plt.title("cert-sal")
# Out:
# Text(0.5, 1.0, 'cert-sal')

# %%
plt.scatter(df["Project Manager Experience"],y,color="g")
plt.xlabel("proj-man-exp")
plt.ylabel("salary")
plt.title("proj-saL")
# Out:
# Text(0.5, 1.0, 'proj-saL')

# %%
import seaborn as sns
sns.regplot(x=df["Total Experience"],y=y)
# Out:
# <Axes: xlabel='Total Experience', ylabel='Salary'>

# %%
sns.regplot(x=df["Team Lead Experience"],y=y,color="r")
# Out:
# <Axes: xlabel='Team Lead Experience', ylabel='Salary'>

# %%
sns.regplot(x=df["Certifications"],y=y,color="m")
# Out:
# <Axes: xlabel='Certifications', ylabel='Salary'>

# %%
sns.regplot(x=df["Project Manager Experience"],y=y,color="g")
# Out:
# <Axes: xlabel='Project Manager Experience', ylabel='Salary'>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=1)
x_train
# Out:
#      Total Experience  Team Lead Experience  Project Manager Experience  \
# 731                 9                     0                           5
# 716                14                     6                           5
# 640                14                    11                           1
# 804                13                    12                           0
# 737                 7                     0                           4
# ..                ...                   ...                         ...
# 767                 5                     4                           0
# 72                 12                     9                           2
# 908                 9                     2                           0
# 235                 3                     1                           1
# 37                 11                     2                           6
#
#      Certifications
# 731               2
# 716               2
# 640               1
# ...

# %%
x_test
# Out:
#      Total Experience  Team Lead Experience  Project Manager Experience  \
# 507                 6                     1                           3
# 818                 6                     1                           1
# 452                 6                     0                           5
# 368                 2                     0                           0
# 242                 9                     2                           0
# ..                ...                   ...                         ...
# 459                 1                     0                           0
# 415                 1                     0                           0
# 61                 14                     7                           1
# 347                 6                     3                           2
# 349                 1                     0                           0
#
#      Certifications
# 507               2
# 818               0
# 452               4
# ...

# %%
y_train
# Out:
# 731     90052.295726
# 716    114485.330984
# 640    118277.563232
# 804    120408.833638
# 737     74102.535163
#            ...
# 767     75766.256100
# 72     109778.022330
# 908     81919.172582
# 235     68571.608473
# 37     103291.737271
# Name: Salary, Length: 700, dtype: float64

# %%
y_test
# Out:
# 507     74346.721685
# 818     66907.856670
# 452     64233.285401
# 368     59183.692759
# 242     79729.796445
#            ...
# 459     56085.029748
# 415     52084.016906
# 61     105731.168307
# 347     80931.592285
# 349     56422.064902
# Name: Salary, Length: 300, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([ 74483.96086857,  71562.96370088,  75471.3349415 ,  57582.68026837,
#         81688.48381756,  83122.38103121,  59446.18456758, 108743.48727614,
#         88325.20289712,  94096.23381685,  95514.41116246,  71923.64817803,
#        118035.19840475,  67598.99734563,  53827.87411262,  62868.1038035 ,
#         79102.41437693,  68292.5687426 ,  57985.68598374,  90035.98673158,
#         73356.34920456,  92162.61072209,  71132.1604282 ,  77918.36297817,
#         63592.70975215,  54633.88554336,  67486.55731186,  55036.89125873,
#         66068.37996624,  69684.14471803, 102178.92779935,  64398.72118289,
#         96781.06423045,  63119.58524124,  72481.41516539,  96239.01711111,
#         67125.87283472,  74093.43802688,  59919.3090785 ,  54633.88554336,
#         79448.98035755, 108731.00440246,  58388.69169911, 104876.24108662,
#         85694.77141104,  73690.43231151, 104432.95494026, 108340.48156077,
# ...

# %%
print("slope is",list((zip(x,model.coef_))))
# Out:
# slope is [('Total Experience', np.float64(2948.794725006278)), ('Team Lead Experience', np.float64(1933.6230947578083)), ('Project Manager Experience', np.float64(1057.4928684734027)), ('Certifications', np.float64(403.00571537052656))]

# %%
print("constant is",model.intercept_)
# Out:
# constant is 50879.07938761546

# %%
df1=pd.DataFrame({"actual value":y_test,"predicted value":y_pred,"difference":y_test-y_pred})
df1
# Out:
#       actual value  predicted value    difference
# 507   74346.721685     74483.960869   -137.239183
# 818   66907.856670     71562.963701  -4655.107031
# 452   64233.285401     75471.334942 -11238.049541
# 368   59183.692759     57582.680268   1601.012490
# 242   79729.796445     81688.483818  -1958.687372
# ..             ...              ...           ...
# 459   56085.029748     53827.874113   2257.155635
# 415   52084.016906     53827.874113  -1743.857206
# 61   105731.168307    108367.082931  -2635.914624
# 347   80931.592285     77696.719905   3234.872380
# 349   56422.064902     54230.879828   2191.185074
#
# [300 rows x 3 columns]

# %%
from sklearn.metrics import mean_absolute_error
MAE=mean_absolute_error(y_test,y_pred)
MAE
# Out:
# 3947.9072576506683

# %%
from sklearn.metrics import mean_absolute_percentage_error
MAPE=mean_absolute_percentage_error(y_test,y_pred)
MAPE
# Out:
# 0.05246047860129205

# %%
from sklearn.metrics import mean_squared_error
MSE=mean_squared_error(y_test,y_pred)
MSE
# Out:
# 24391623.92122533

# %%
from sklearn.metrics import root_mean_squared_error
RMSE=root_mean_squared_error(y_test,y_pred)
RMSE
# Out:
# 4938.787697525106

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)
score
# Out:
# 0.9232417551963441
