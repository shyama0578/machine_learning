# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("concrete_data.csv")
df
# Out:
#       Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0      540.0                 0.0      0.0  162.0               2.5
# 1      540.0                 0.0      0.0  162.0               2.5
# 2      332.5               142.5      0.0  228.0               0.0
# 3      332.5               142.5      0.0  228.0               0.0
# 4      198.6               132.4      0.0  192.0               0.0
# ...      ...                 ...      ...    ...               ...
# 1025   276.4               116.0     90.3  179.6               8.9
# 1026   322.2                 0.0    115.6  196.0              10.4
# 1027   148.5               139.4    108.6  192.7               6.1
# 1028   159.1               186.7      0.0  175.6              11.3
# 1029   260.9               100.5     78.3  200.6               8.6
#
#       Coarse Aggregate  Fine Aggregate  Age  Strength
# 0               1040.0           676.0   28     79.99
# ...

# %%
df.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
df.tail()
# Out:
#       Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 1025   276.4               116.0     90.3  179.6               8.9
# 1026   322.2                 0.0    115.6  196.0              10.4
# 1027   148.5               139.4    108.6  192.7               6.1
# 1028   159.1               186.7      0.0  175.6              11.3
# 1029   260.9               100.5     78.3  200.6               8.6
#
#       Coarse Aggregate  Fine Aggregate  Age  Strength
# 1025             870.1           768.3   28     44.28
# 1026             817.9           813.4   28     31.18
# 1027             892.4           780.0   28     23.70
# 1028             989.6           788.9   28     32.77
# 1029             864.5           761.5   28     32.40

# %%
df.shape
# Out:
# (1030, 9)

# %%
df.columns
# Out:
# Index(['Cement', 'Blast Furnace Slag', 'Fly Ash', 'Water', 'Superplasticizer',
#        'Coarse Aggregate', 'Fine Aggregate', 'Age', 'Strength'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Cement                float64
# Blast Furnace Slag    float64
# Fly Ash               float64
# Water                 float64
# Superplasticizer      float64
# Coarse Aggregate      float64
# Fine Aggregate        float64
# Age                     int64
# Strength              float64
# dtype: object

# %%
df.isna().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %%
x=df.iloc[:,:-1]
x
# Out:
#       Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0      540.0                 0.0      0.0  162.0               2.5
# 1      540.0                 0.0      0.0  162.0               2.5
# 2      332.5               142.5      0.0  228.0               0.0
# 3      332.5               142.5      0.0  228.0               0.0
# 4      198.6               132.4      0.0  192.0               0.0
# ...      ...                 ...      ...    ...               ...
# 1025   276.4               116.0     90.3  179.6               8.9
# 1026   322.2                 0.0    115.6  196.0              10.4
# 1027   148.5               139.4    108.6  192.7               6.1
# 1028   159.1               186.7      0.0  175.6              11.3
# 1029   260.9               100.5     78.3  200.6               8.6
#
#       Coarse Aggregate  Fine Aggregate  Age
# 0               1040.0           676.0   28
# 1               1055.0           676.0   28
# ...

# %%
y=df.iloc[:,-1]
y
# Out:
# 0       79.99
# 1       61.89
# 2       40.27
# 3       41.05
# 4       44.30
#         ...
# 1025    44.28
# 1026    31.18
# 1027    23.70
# 1028    32.77
# 1029    32.40
# Name: Strength, Length: 1030, dtype: float64

# %%
plt.scatter(df["Cement"],y)
plt.xlabel("cement",fontsize=18)
plt.ylabel("strength",fontsize=18)
plt.title("cement-strngth scatter plot",fontsize=20)
# Out:
# Text(0.5, 1.0, 'cement-strngth scatter plot')

# %%
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age
plt.scatter(df["Blast Furnace Slag"],y,color="r")
plt.xlabel("blast furnace",fontsize=18)
plt.ylabel("strength",fontsize=18)
plt.title("blast-stregth scatterplt",fontsize=20)
# Out:
# Text(0.5, 1.0, 'blast-stregth scatterplt')

# %%
plt.scatter(df["Fly Ash"],y,color="m")
plt.xlabel("fly ash",fontsize=18)
plt.ylabel("strength",fontsize=18)
plt.title("fly ash-strength",fontsize=20)
# Out:
# Text(0.5, 1.0, 'fly ash-strength')

# %%
plt.scatter(df["Water"],y,color="k")
plt.xlabel("Water",fontsize=18)
plt.ylabel("strength",fontsize=18)
plt.title("water-strength",fontsize=20)
# Out:
# Text(0.5, 1.0, 'water-strength')

# %%
plt.scatter(df["Superplasticizer"],y,color="g")
plt.xlabel("superplasticizer",fontsize=18)
plt.ylabel("strength",fontsize=18)
plt.title("superplas-strength",fontsize=20)
# Out:
# Text(0.5, 1.0, 'superplas-strength')

# %%
plt.scatter(df["Coarse Aggregate"],y,color="c")
plt.xlabel("coarse",fontsize=18)
plt.ylabel("strength",fontsize=18)
plt.title("coarse-strength",fontsize=20)
# Out:
# Text(0.5, 1.0, 'coarse-strength')

# %%
plt.scatter(df["Fine Aggregate"],y,color="y")
plt.xlabel("fine aggregate",fontsize=18)
plt.ylabel("strength",fontsize=18)
plt.title("fine-strength",fontsize=20)
# Out:
# Text(0.5, 1.0, 'fine-strength')

# %%
plt.scatter(df["Age"],y,color="r")
plt.xlabel("age",fontsize=18)
plt.ylabel("strength",fontsize=18)
plt.title("age-strength",fontsize=20)
# Out:
# Text(0.5, 1.0, 'age-strength')

# %%
sns.regplot(x=df["Cement"],y=y)
# Out:
# <Axes: xlabel='Cement', ylabel='Strength'>

# %%
sns.regplot(x=df["Blast Furnace Slag"],y=y,color="m")
# Out:
# <Axes: xlabel='Blast Furnace Slag', ylabel='Strength'>

# %%
sns.regplot(x=df["Coarse Aggregate"],y=y,color="k")
# Out:
# <Axes: xlabel='Coarse Aggregate', ylabel='Strength'>

# %%
sns.regplot(x=df["Fine Aggregate"],y=y,color="r")
# Out:
# <Axes: xlabel='Fine Aggregate', ylabel='Strength'>

# %%
sns.regplot(x=df["Fly Ash"],y=y,color="g")
# Out:
# <Axes: xlabel='Fly Ash', ylabel='Strength'>

# %%
sns.regplot(x=df["Superplasticizer"],y=y,color="y")
# Out:
# <Axes: xlabel='Superplasticizer', ylabel='Strength'>

# %%
sns.regplot(x=df["Water"],y=y,color="c")
# Out:
# <Axes: xlabel='Water', ylabel='Strength'>

# %%
sns.regplot(x=df["Age"],y=y,color="k")
# Out:
# <Axes: xlabel='Age', ylabel='Strength'>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=0)
x_train
# Out:
#      Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 772   382.0                 0.0      0.0  186.0               0.0
# 997   310.0               142.8      0.0  167.9              10.0
# 724   310.0                 0.0      0.0  192.0               0.0
# 167   475.0               118.8      0.0  181.1               8.9
# 764   385.0                 0.0      0.0  186.0               0.0
# ..      ...                 ...      ...    ...               ...
# 277   251.4                 0.0    118.3  188.5               5.8
# 763   385.0                 0.0      0.0  186.0               0.0
# 835   144.0                 0.0    175.0  158.0              18.0
# 559   239.6               359.4      0.0  185.7               0.0
# 684   192.0               288.0      0.0  192.0               0.0
#
#      Coarse Aggregate  Fine Aggregate  Age
# 772            1047.0           739.0    7
# 997             914.3           804.0   28
# ...

# %%
x_test
# Out:
#      Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 747   500.0                 0.0      0.0  200.0               0.0
# 718   122.6               183.9      0.0  203.5               0.0
# 175   362.6               189.0      0.0  164.9              11.6
# 828   522.0                 0.0      0.0  146.0               0.0
# 713   157.0               236.0      0.0  192.0               0.0
# ..      ...                 ...      ...    ...               ...
# 156   286.3               200.9      0.0  144.7              11.2
# 222   166.1                 0.0    163.3  176.5               4.5
# 665   173.0               116.0      0.0  192.0               0.0
# 210   230.0                 0.0    118.3  195.5               4.6
# 306   277.1                 0.0     97.4  160.6              11.8
#
#      Coarse Aggregate  Fine Aggregate  Age
# 747            1125.0           613.0    3
# 718             958.2           800.1    7
# ...

# %%
y_train
# Out:
# 772    24.00
# 997    45.30
# 724    35.76
# 167    74.19
# 764    14.70
#        ...
# 277    36.97
# 763     6.27
# 835    15.42
# 559    39.44
# 684    50.73
# Name: Strength, Length: 721, dtype: float64

# %%
y_test
# Out:
# 747    26.06
# 718    10.35
# 175    79.30
# 828    74.99
# 713     9.69
#        ...
# 156    72.99
# 222    28.63
# 665    11.39
# 210    20.08
# 306    48.28
# Name: Strength, Length: 309, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
y_pred
# Out:
# array([39.47333647, 14.08181113, 60.90617502, 53.49216504, 23.95652105,
#        53.38494262, 45.65496577, 26.92130645, 52.88683822, 37.13787653,
#        16.55157144, 38.81020387, 29.47532698, 35.14012862, 47.80046883,
#        56.45734447, 35.43954133, 29.20286434, 48.34810942, 35.12300254,
#        53.44653832, 31.87269795, 32.38089157, 47.90405414, 23.4547955 ,
#        23.32931202, 69.81924352, 26.29647636, 56.45734447, 47.80199424,
#        18.7288124 , 36.32839137, 17.2570425 , 19.75384858, 24.46017771,
#        15.0536384 , 52.94088734, 27.79184471, 26.73627367, 25.95801099,
#        52.51684761, 30.33783679, 26.02387955, 35.01487363, 53.0415329 ,
#        54.01405889, 30.33153322, 43.96402577, 27.4875974 , 56.65557931,
#        36.417551  , 19.18663184, 23.29973858, 34.35993512, 43.00786877,
#        47.19325832, 35.40203995, 52.88814999, 59.89779143, 36.30933765,
#        30.98904611, 20.58209173, 50.33598027, 55.61201479, 20.36535531,
# ...

# %%
print("slope is",list((zip(x,lr.coef_))))
# Out:
# slope is [('Cement', np.float64(0.12132219951786512)), ('Blast Furnace Slag', np.float64(0.10790306559516541)), ('Fly Ash', np.float64(0.09202680690494455)), ('Water', np.float64(-0.1325122107209872)), ('Superplasticizer', np.float64(0.3544672939399408)), ('Coarse Aggregate', np.float64(0.023773237330166033)), ('Fine Aggregate', np.float64(0.02425020005911098)), ('Age', np.float64(0.11101382142583908))]

# %%
print("constant is",lr.intercept_)
# Out:
# constant is -36.628627243939974

# %%
df1=pd.DataFrame({"ACTUAL VALUE":y_test,"predicted":y_pred,"difference":y_test-y_pred})
df1
# Out:
#      ACTUAL VALUE  predicted  difference
# 747         26.06  39.473336  -13.413336
# 718         10.35  14.081811   -3.731811
# 175         79.30  60.906175   18.393825
# 828         74.99  53.492165   21.497835
# 713          9.69  23.956521  -14.266521
# ..            ...        ...         ...
# 156         72.99  54.168415   18.821585
# 222         28.63  27.058369    1.571631
# 665         11.39  15.497694   -4.107694
# 210         20.08  22.309228   -2.229228
# 306         48.28  36.349036   11.930964
#
# [309 rows x 3 columns]

# %%
from sklearn.metrics import mean_absolute_error
MAE=mean_absolute_error(y_test,y_pred)
MAE
# Out:
# 7.775625710189035

# %%
from sklearn.metrics import mean_absolute_percentage_error
MAPE=mean_absolute_percentage_error(y_test,y_pred)
MAPE
# Out:
# 0.30399656208704356

# %%
from sklearn.metrics import mean_squared_error
MSE=mean_squared_error(y_test,y_pred)
MSE
# Out:
# 93.61873598596337

# %%
from sklearn.metrics import root_mean_squared_error
RMSE=root_mean_squared_error(y_test,y_pred)
RMSE
# Out:
# 9.675677546609506

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)
score
# Out:
# 0.6352987285077925

# %%
from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=3)
x_train_poly=poly.fit_transform(x_train)
x_test_poly=poly.fit_transform(x_test)

# %%
lr1=LinearRegression()
lr1.fit(x_train_poly,y_train)
y_pred1=lr1.predict(x_test_poly)
y_pred1
# Out:
# array([27.52864938, 11.11347486, 77.67295787, 57.74360318, 11.80389568,
#        40.21103579, 61.92152991, 20.34773561, 76.42487485, 49.97593084,
#        16.59666528, 43.28582149, 37.58717472, 17.21546448, 59.52467188,
#        63.05531279, 33.34952363, 36.81526318, 58.45109382, 37.96048428,
#        55.37318978, 25.28039987, 30.89258498, 56.89185572, 22.26118826,
#        27.10450638, 75.63356776, 21.69634473, 63.05531279, 69.40904242,
#        21.24445419, 49.13229516, 22.33077668, 36.61518335, 23.82642603,
#         7.39247391, 36.58751489, 25.26881789, 26.32223042, 29.45037806,
#        49.18441528, 41.50525982, 23.12199847, 41.40224049, 76.14487641,
#        36.81868597, 26.6043022 , 41.67295201, 32.71910043, 58.40183325,
#        42.85446692, 23.13900171, 21.57612934, 39.35792498, 56.15476702,
#        41.90652949, 42.39224293, 52.49254896, 69.89412252, 51.86305108,
#        34.08887646, 20.18507403, 52.97643432, 33.581305  , 13.56993526,
# ...

# %%
MAE=mean_absolute_error(y_test,y_pred1)
MAE
# Out:
# 4.972560751362539

# %%
MAPE=mean_absolute_percentage_error(y_test,y_pred1)
MAPE
# Out:
# 0.16329975773515515

# %%
MSE=mean_squared_error(y_test,y_pred1)
MSE
# Out:
# 52.02031175010994

# %%
RMSE=root_mean_squared_error(y_test,y_pred1)
RMSE
# Out:
# 7.212510779895579

# %%
score=r2_score(y_test,y_pred1)
score
# Out:
# 0.7973496048747054
