# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("manufacturing.csv")
df
# Out:
#       Temperature (°C)  Pressure (kPa)  Temperature x Pressure  \
# 0           209.762701        8.050855             1688.769167
# 1           243.037873       15.812068             3842.931469
# 2           220.552675        7.843130             1729.823314
# 3           208.976637       23.786089             4970.736918
# 4           184.730960       15.797812             2918.345014
# ...                ...             ...                     ...
# 3952        156.811578       21.794290             3417.596965
# 3953        197.850406        8.291704             1640.516924
# 3954        241.357144       16.391910             3956.304672
# 3955        209.040239       23.809936             4977.234763
# 3956        163.359996       24.332133             3974.897121
#
#       Material Fusion Metric  Material Transformation Metric  Quality Rating
# 0               44522.217074                    9.229576e+06       99.999971
# ...

# %%
df.head()
# Out:
#    Temperature (°C)  Pressure (kPa)  Temperature x Pressure  \
# 0        209.762701        8.050855             1688.769167
# 1        243.037873       15.812068             3842.931469
# 2        220.552675        7.843130             1729.823314
# 3        208.976637       23.786089             4970.736918
# 4        184.730960       15.797812             2918.345014
#
#    Material Fusion Metric  Material Transformation Metric  Quality Rating
# 0            44522.217074                    9.229576e+06       99.999971
# 1            63020.764997                    1.435537e+07       99.985703
# 2            49125.950249                    1.072839e+07       99.999758
# 3            57128.881547                    9.125702e+06       99.999975
# 4            38068.201283                    6.303792e+06      100.000000

# %%
df.tail()
# Out:
#       Temperature (°C)  Pressure (kPa)  Temperature x Pressure  \
# 3952        156.811578       21.794290             3417.596965
# 3953        197.850406        8.291704             1640.516924
# 3954        241.357144       16.391910             3956.304672
# 3955        209.040239       23.809936             4977.234763
# 3956        163.359996       24.332133             3974.897121
#
#       Material Fusion Metric  Material Transformation Metric  Quality Rating
# 3952            34941.963896                    3.855501e+06      100.000000
# 3953            39714.857236                    7.744742e+06       99.999997
# 3954            62657.690952                    1.405957e+07       99.989318
# 3955            57195.985528                    9.134036e+06       99.999975
# 3956            41092.392901                    4.358913e+06      100.000000

# %%
df.shape
# Out:
# (3957, 6)

# %%
df.dtypes
# Out:
# Temperature (°C)                  float64
# Pressure (kPa)                    float64
# Temperature x Pressure            float64
# Material Fusion Metric            float64
# Material Transformation Metric    float64
# Quality Rating                    float64
# dtype: object

# %%
df.isna().sum()
# Out:
# Temperature (°C)                  0
# Pressure (kPa)                    0
# Temperature x Pressure            0
# Material Fusion Metric            0
# Material Transformation Metric    0
# Quality Rating                    0
# dtype: int64

# %%
x=df.iloc[:,:-1]
x
# Out:
#       Temperature (°C)  Pressure (kPa)  Temperature x Pressure  \
# 0           209.762701        8.050855             1688.769167
# 1           243.037873       15.812068             3842.931469
# 2           220.552675        7.843130             1729.823314
# 3           208.976637       23.786089             4970.736918
# 4           184.730960       15.797812             2918.345014
# ...                ...             ...                     ...
# 3952        156.811578       21.794290             3417.596965
# 3953        197.850406        8.291704             1640.516924
# 3954        241.357144       16.391910             3956.304672
# 3955        209.040239       23.809936             4977.234763
# 3956        163.359996       24.332133             3974.897121
#
#       Material Fusion Metric  Material Transformation Metric
# 0               44522.217074                    9.229576e+06
# 1               63020.764997                    1.435537e+07
# ...

# %%
y=df.iloc[:,-1]
y
# Out:
# 0        99.999971
# 1        99.985703
# 2        99.999758
# 3        99.999975
# 4       100.000000
#            ...
# 3952    100.000000
# 3953     99.999997
# 3954     99.989318
# 3955     99.999975
# 3956    100.000000
# Name: Quality Rating, Length: 3957, dtype: float64

# %%
plt.scatter(df["Temperature (°C)"],y)
plt.xlabel("temperature",fontsize=18)
plt.ylabel("quality rating",fontsize=18)
plt.title("temp-rating",fontsize=20)
# Out:
# Text(0.5, 1.0, 'temp-rating')

# %%
plt.scatter(df["Pressure (kPa)"],y,color="r")
plt.xlabel("pressure",fontsize=18)
plt.ylabel("quality rating",fontsize=18)
plt.title("pressure-rating",fontsize=20)
# Out:
# Text(0.5, 1.0, 'pressure-rating')

# %%
plt.scatter(df["Temperature x Pressure"],y,color="m")
plt.xlabel("temp-press",fontsize=18)
plt.ylabel("quality rating",fontsize=18)
plt.title("temp-press-rating",fontsize=20)
# Out:
# Text(0.5, 1.0, 'temp-press-rating')

# %%
plt.scatter(df["Material Fusion Metric"],y,color="k")
plt.xlabel("meterial fusion",fontsize=18)
plt.ylabel("quality rating",fontsize=18)
plt.title("meterial-rating",fontsize=20)
# Out:
# Text(0.5, 1.0, 'meterial-rating')

# %%
plt.scatter(df["Material Transformation Metric"],y,color="g")
plt.xlabel("material transformation",fontsize=18)
plt.ylabel("quality rating",fontsize=18)
plt.title("material trans-rating",fontsize=20)
# Out:
# Text(0.5, 1.0, 'material trans-rating')

# %%
sns.regplot(x=df["Temperature (°C)"],y=y)
# Out:
# <Axes: xlabel='Temperature (°C)', ylabel='Quality Rating'>

# %%
sns.regplot(x=df["Pressure (kPa)"],y=y,color="m")
# Out:
# <Axes: xlabel='Pressure (kPa)', ylabel='Quality Rating'>

# %%
sns.regplot(x=df["Temperature x Pressure"],y=y,color="r")
# Out:
# <Axes: xlabel='Temperature x Pressure', ylabel='Quality Rating'>

# %%
sns.regplot(x=df["Material Fusion Metric"],y=y,color="k")
# Out:
# <Axes: xlabel='Material Fusion Metric', ylabel='Quality Rating'>

# %%
sns.regplot(x=df["Material Transformation Metric"],y=y,color="g")
plt.xlabel("material trans",fontsize=18)
plt.ylabel("quality rating",fontsize=18)
plt.title("material trans-rating",fontsize=20)
# Out:
# Text(0.5, 1.0, 'material trans-rating')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=0)
x_train
# Out:
#       Temperature (°C)  Pressure (kPa)  Temperature x Pressure  \
# 98          265.788006       22.812104             6063.183507
# 1446        281.579692       10.898344             3068.752215
# 1525        281.649676       16.711005             4706.649020
# 40          171.901580       21.600059             3713.084262
# 3525        212.382292        9.999574             2123.732409
# ...                ...             ...                     ...
# 835         195.876910       11.015577             2157.697202
# 3264        137.036400       14.808613             2029.319036
# 1653        205.663025       23.757125             4885.962265
# 2607        272.433253        8.157178             2222.286575
# 2732        251.353121       13.812065             3471.705561
#
#       Material Fusion Metric  Material Transformation Metric
# 98              82514.501772                    1.877561e+07
# 1446            80581.561347                    2.232552e+07
# ...

# %%
x_test
# Out:
#       Temperature (°C)  Pressure (kPa)  Temperature x Pressure  \
# 3256        158.637458       11.608450             1841.535039
# 142         187.172985        7.079642             1325.117701
# 2623        263.449717       17.486238             4606.744412
# 3741        178.757649       18.348884             3280.003386
# 2858        263.411397       13.758436             3624.128934
# ...                ...             ...                     ...
# 3809        299.142537       14.092464             4215.655374
# 1151        226.797384       16.336513             3705.078382
# 3252        296.860346       21.746266             6455.604110
# 601         165.597600       13.185933             2183.558864
# 2888        247.096760       14.483275             3578.770345
#
#       Material Fusion Metric  Material Transformation Metric
# 3256            26730.152796                    3.992111e+06
# 142             35388.567392                    6.557317e+06
# ...

# %%
y_train
# Out:
# 98       99.387157
# 1446     93.077619
# 1525     93.005691
# 40      100.000000
# 3525     99.999950
#            ...
# 835      99.999998
# 3264    100.000000
# 1653     99.999987
# 2607     98.270435
# 2732     99.941265
# Name: Quality Rating, Length: 2769, dtype: float64

# %%
y_test
# Out:
# 3256    100.000000
# 142     100.000000
# 2623     99.577102
# 3741    100.000000
# 2858     99.579641
#            ...
# 3809     12.124021
# 1151     99.999217
# 3252     36.303721
# 601     100.000000
# 2888     99.971334
# Name: Quality Rating, Length: 1188, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
y_pred
# Out:
# array([102.68707798, 104.99892029,  88.86276693, ...,  73.53442614,
#        102.93290408,  94.31054566], shape=(1188,))

# %%
print("slope is",list((zip(x,lr.coef_))))
# Out:
# slope is [('Temperature (°C)', np.float64(0.230447094237908)), ('Pressure (kPa)', np.float64(-0.6287776931750101)), ('Temperature x Pressure', np.float64(0.0009713252765411522)), ('Material Fusion Metric', np.float64(0.000632000380677282)), ('Material Transformation Metric', np.float64(-4.710035343740155e-06))]

# %%
print("constant is",lr.intercept_)
# Out:
# constant is 73.54945716271692

# %%
from sklearn.metrics import mean_absolute_error
MAE=mean_absolute_error(y_test,y_pred)
MAE
# Out:
# 5.871151674188839

# %%
from sklearn.metrics import mean_absolute_percentage_error
MAPE=mean_absolute_percentage_error(y_test,y_pred)
MAPE
# Out:
# 0.18611194558685432

# %%
from sklearn.metrics import mean_squared_error
MSE=mean_squared_error(y_test,y_pred)
MSE
# Out:
# 95.90218892753283

# %%
from sklearn.metrics import root_mean_squared_error
RMSE=root_mean_squared_error(y_test,y_pred)
RMSE
# Out:
# 9.792966298703005

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)
score
# Out:
# 0.523202417721826

# %%
from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=3)
x_train_poly=poly.fit_transform(x_train)
x_test_poly=poly.fit_transform(x_test)

# %%
lr1=LinearRegression()
lr1.fit(x_train_poly,y_train)
y_pred1=lr1.predict(x_test_poly)
y_pred1
# Out:
# array([101.00090799,  99.9346352 , 102.86457938, ...,  43.38734034,
#        100.79148359, 101.26606946], shape=(1188,))

# %%
MAE=mean_absolute_error(y_test,y_pred1)
MAE
# Out:
# 1.9802411618069584

# %%
MAPE=mean_absolute_percentage_error(y_test,y_pred1)
MAPE
# Out:
# 0.06061710038004384

# %%
MSE=mean_squared_error(y_test,y_pred1)
MSE
# Out:
# 8.98464117026257

# %%
score=r2_score(y_test,y_pred1)
score
# Out:
# 0.9553309967632212
